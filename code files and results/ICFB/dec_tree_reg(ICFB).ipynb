# %% [markdown]
# # Decision Tree Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('DummyData.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ##Splitting the Dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %% [markdown]
# ## Training the Decision Tree Regression model on the whole dataset

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X_train , y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# ## Predicting a new result on the Test set

# %%
y_pred = regressor.predict(X_test)

# %%
print(y_pred)
# Out:
# [ 2.9  12.36 14.77 17.25  8.05 10.65 20.99  8.05 14.84 17.68 13.71 26.58
#   5.75  8.16 15.72 13.71  8.44 20.37  2.9   4.17 11.3   6.16 15.42 11.54
#   3.17 17.5  22.88 13.71 23.35  4.67 26.13  8.44  2.94 17.76 14.77  2.94
#  15.72 17.74 11.3  27.05  8.55 19.53  3.32  5.66 20.99  3.17  3.19 13.04
#  23.35  2.9  17.25  8.29  4.01 11.54  2.94 15.68 17.25 25.46 15.72 23.38]

# %% [markdown]
# ##Evaluating the model performance

# %%
y_test_orginal = y_test.reshape(-1, 1)

# %%
from sklearn.metrics import mean_squared_error, r2_score
print('Mean Squared Error:', mean_squared_error(y_test_orginal, y_pred))
print('R-squared:', r2_score(y_test_orginal, y_pred))
# Out:
# Mean Squared Error: 79.36643000000002
# R-squared: -0.29504395643037085

# %% [markdown]
# ## Visualising the Decision Tree Regression results (higher resolution)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, color = 'blue', label='Predicted')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle = '--', label = 'Ideal fit')
plt.xlabel('Actual Values of Solid Circulation Rate')
plt.ylabel('Predicted Values of Solid circulation Rate')
plt.title('Decision Tree Regression predictions VS Actual values')
plt.legend()
plt.show()
